# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

sns.set_style("darkgrid")
sns.set_palette("colorblind")
sns.set_context("paper")

# %%
df = pd.read_csv('xy_match_average.csv')
df
# Out:
#               x         y
# 0      0.132530  0.636364
# 1      0.146341  0.583333
# 2      0.158416  0.687500
# 3      0.214876  0.807692
# 4      0.250000  0.600000
# ...         ...       ...
# 24311  1.000000  0.631579
# 24312  1.000000  0.750000
# 24313  1.000000  0.555556
# 24314  1.000000  0.578947
# 24315  1.000000  0.625000
#
# [24316 rows x 2 columns]

# %%
fig, ax = plt.subplots()
# set ylabel
ax.set_ylabel('y')
# set xlabel
ax.set_xlabel('x')
# xlim, ylim
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

plt.scatter(df['x'], df['y'], s=0.05)
plt.show()

# %%
sns.displot(df['x'], kde=False, bins=50)
# Out:
# /var/folders/tj/yg7jf9sd6z54nrj32_wv_rp40000gn/T/ipykernel_46117/1425953260.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['x'], hist=False, bins=50)
# <Axes: xlabel='x', ylabel='Density'>

# %%
sns.displot(df['y'], kde=False, bins=30)

# %%
sns.jointplot(x=df['x'], y=df['y'], kind='hex')

# %% [markdown]
# df['w']=df['x']*df['y']
# df.to_csv('xy_match_average.csv', index=False)

# %%
sns.jointplot(x=df['x'], y=df['w'], kind='hex')

# %%
sns.regplot(x=df['x'], y=df['y'])
# Out:
# <Axes: xlabel='x', ylabel='y'>
