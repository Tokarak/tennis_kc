# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

sns.set_style("darkgrid")
sns.set_palette("colorblind")
sns.set_context("paper")

# %%
df = pd.read_csv('xy_match_average.csv')
df
# Out:
#               x         y         w
# 0      0.132530  0.636364  0.084337
# 1      0.146341  0.583333  0.085366
# 2      0.158416  0.687500  0.108911
# 3      0.214876  0.807692  0.173554
# 4      0.250000  0.600000  0.150000
# ...         ...       ...       ...
# 24311  1.000000  0.631579  0.631579
# 24312  1.000000  0.750000  0.750000
# 24313  1.000000  0.555556  0.555556
# 24314  1.000000  0.578947  0.578947
# 24315  1.000000  0.625000  0.625000
#
# [24316 rows x 3 columns]

# %%
fig, ax = plt.subplots()
# set ylabel
ax.set_ylabel('y')
# set xlabel
ax.set_xlabel('x')
# xlim, ylim
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

plt.scatter(df['x'], df['y'], s=0.05)
plt.show()

# %%
sns.displot(df['x'], kde=False, bins=50)

# %%
sns.displot(df['y'], kde=False, bins=30)

# %%
sns.jointplot(x=df['x'], y=df['y'], kind='hex')

# %% [markdown]
# df['w']=df['x']*df['y']
# df.to_csv('xy_match_average.csv', index=False)

# %%
sns.jointplot(x=df['x'], y=df['w'], kind='hex')

# %%
p = sns.regplot(x=df['x'], y=df['y'], data=df, )

# %%
line = p.get_children()[1]
#get equation from line
points = line.get_xydata()
points
# get the slope and intercept
slope = (points[99,1] - points[0,1]) / (points[99,0] - points[0,0])
intercept = points[0,1] - (slope * points[0,0])
print("Line: y = {:.6f}x + {:.6f}".format(slope, intercept))
# Out:
# Line: y = -0.382250x + 0.909423

# %%
sns.residplot(x=df['x'], y=df['y'],)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.clustermap(df[["x", "y"]])
# Out:
# /Users/tok/opt/miniconda3/envs/tennis_kc/lib/python3.9/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
